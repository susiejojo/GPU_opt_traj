# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/inv_comp.py
# Out:
# (100, 21) (100, 21) (100, 21)

# %%
#16-15
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_16.py 15
# Out:
# Mean compute time for each iter: 0.0082423663091564
# <Figure size 480x480 with 1 Axes>
# 8 violations out of 120
# <Figure size 480x480 with 1 Axes>

# %%
#16-20
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_16.py 20
# Out:
# Mean compute time for each iter: 0.008219652519914095
# <Figure size 480x480 with 1 Axes>
# 10 violations out of 120
# <Figure size 480x480 with 1 Axes>

# %%
#16-25
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_16.py 25
# Out:
# Mean compute time for each iter: 0.007240649454579325
# <Figure size 480x480 with 1 Axes>
# 11 violations out of 120
# <Figure size 480x480 with 1 Axes>

# %%
#16-30
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_16.py 30
# Out:
# Mean compute time for each iter: 0.007161674614181978
# <Figure size 480x480 with 1 Axes>
# 12 violations out of 120
# <Figure size 480x480 with 1 Axes>

# %%
#16-35
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_16.py 35
# Out:
# Mean compute time for each iter: 0.006364997737632247
# <Figure size 480x480 with 1 Axes>
# 12 violations out of 120
# <Figure size 480x480 with 1 Axes>

# %%
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/inv_comp.py
# Out:
# (100, 21) (100, 21) (100, 21)

# %%
#32-12
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_32.py 12
# Out:
# Mean compute time for each iter: 0.020495731510475786
# <Figure size 480x480 with 1 Axes>
# 34 violations out of 496
# <Figure size 480x480 with 1 Axes>

# %%
#32-15
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_32.py 15
# Out:
# Mean compute time for each iter: 0.020156285566891842
# <Figure size 480x480 with 1 Axes>
# 32 violations out of 496
# <Figure size 480x480 with 1 Axes>

# %%
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/inv_comp.py
# Out:
# (100, 21) (100, 21) (100, 21)

# %%
#8-10
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_8.py 10
# Out:
# Mean compute time for each iter: 0.008609701015189559
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 28
# <Figure size 480x480 with 1 Axes>

# %%
#8-12
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_8.py 12
# Out:
# Mean compute time for each iter: 0.00848163010362155
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 28
# <Figure size 480x480 with 1 Axes>

# %%
#8-15
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_8.py 15
# Out:
# Mean compute time for each iter: 0.008952279845793883
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 28
# <Figure size 480x480 with 1 Axes>

# %%
#8-30
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_8.py 30
# Out:
# Mean compute time for each iter: 0.008761960662199643
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 28
# <Figure size 480x480 with 1 Axes>

# %%
#8-60
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_8.py 60
# Out:
# Mean compute time for each iter: 0.008645400733412627
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 28
# <Figure size 480x480 with 1 Axes>

# %%
#8-120
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl
# tcmalloc: large alloc 2167603200 bytes == 0x558fecf90000 @  0x7f48c9fc31e7 0x7f48b78c746e 0x7f48b7917c7b 0x7f48b7917d97 0x7f48b7917fe9 0x7f48b791ad7d 0x7f48b8b407f8 0x7f48b8b3a4b0 0x7f48b8b44a0c 0x7f48b8b34b76 0x7f48b8901fa5 0x7f48b88f7961 0x558f48cdfc38 0x558f48d5363d 0x558f48ce069a 0x558f48d4ea45 0x558f48d4db0e 0x558f48ce077a 0x558f48d52e50 0x558f48d4db0e 0x558f48ce077a 0x558f48d4f86a 0x558f48d4de0d 0x558f48ce077a 0x558f48d4f86a 0x558f48d4db0e 0x558f48ce077a 0x558f48d52e50 0x558f48d4db0e 0x558f48d4d813 0x558f48e17592
# Mean compute time for each iter: 0.04186842580118733
# <Figure size 480x480 with 1 Axes>
# 123 violations out of 2016
# <Figure size 480x480 with 1 Axes>

# %%
#64-15
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_64.py 15
# Out:
# tcmalloc: large alloc 2167611392 bytes == 0x561f5df06000 @  0x7f7a238c51e7 0x561f3cbb7f48 0x561f3cb829c7 0x7f79f022bb32 0x7f79f0446973 0x7f79f044b0bd 0x7f79f044e8ee 0x7f79f04565c0 0x7f79f04485f5 0x561f3cb86050 0x561f3cc7799d 0x561f3cbf9fe9 0x561f3cbf4b0e 0x561f3cb8777a 0x561f3cbf5c9e 0x561f3cbf4b0e 0x561f3cb8777a 0x561f3cbf5c9e 0x561f3cbf4b0e 0x561f3cb8777a 0x561f3cbf5a45 0x561f3cbf4b0e 0x561f3cbf4813 0x561f3ccbe592 0x561f3ccbe90d 0x561f3ccbe7b6 0x561f3cc96103 0x561f3cc95dac 0x7f7a226afbf7 0x561f3cc95c8a
# tcmalloc: large alloc 2167603200 bytes == 0x561fdf238000 @  0x7f7a238c51e7 0x7f7a111c946e 0x7f7a11219c7b 0x7f7a11219d97 0x7f7a11219fe9 0x7f7a1121cd7d 0x7f7a124427f8 0x7f7a1243c4b0 0x7f7a12446a0c 0x7f7a12436b76 0x7f7a12203fa5 0x7f7a121f9961 0x561f3cb86c38 0x561f3cbfa63d 0x561f3cb8769a 0x561f3cbf5a45 0x561f3cbf4b0e 0x561f3cb8777a 0x561f3cbf9e50 0x561f3cbf4b0e 0x561f3cb8777a 0x561f3cbf686a 0x561f3cbf4e0d 0x561f3cb8777a 0x561f3cbf686a 0x561f3cbf4b0e 0x561f3cb8777a 0x561f3cbf9e50 0x561f3cbf4b0e 0x561f3cbf4813 0x561f3ccbe592
# Mean compute time for each iter: 0.04189712920026454
# <Figure size 480x480 with 1 Axes>
# 128 violations out of 2016
# <Figure size 480x480 with 1 Axes>

# %%
#64-20
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_64.py 20
# Out:
# tcmalloc: large alloc 2167611392 bytes == 0x55e56647e000 @  0x7fdcf05511e7 0x55e544e70f48 0x55e544e3b9c7 0x7fdcbceb7b32 0x7fdcbd0d2973 0x7fdcbd0d70bd 0x7fdcbd0da8ee 0x7fdcbd0e25c0 0x7fdcbd0d45f5 0x55e544e3f050 0x55e544f3099d 0x55e544eb2fe9 0x55e544eadb0e 0x55e544e4077a 0x55e544eaec9e 0x55e544eadb0e 0x55e544e4077a 0x55e544eaec9e 0x55e544eadb0e 0x55e544e4077a 0x55e544eaea45 0x55e544eadb0e 0x55e544ead813 0x55e544f77592 0x55e544f7790d 0x55e544f777b6 0x55e544f4f103 0x55e544f4edac 0x7fdcef33bbf7 0x55e544f4ec8a
# tcmalloc: large alloc 2167603200 bytes == 0x55e5e77b0000 @  0x7fdcf05511e7 0x7fdcdde5546e 0x7fdcddea5c7b 0x7fdcddea5d97 0x7fdcddea5fe9 0x7fdcddea8d7d 0x7fdcdf0ce7f8 0x7fdcdf0c84b0 0x7fdcdf0d2a0c 0x7fdcdf0c2b76 0x7fdcdee8ffa5 0x7fdcdee85961 0x55e544e3fc38 0x55e544eb363d 0x55e544e4069a 0x55e544eaea45 0x55e544eadb0e 0x55e544e4077a 0x55e544eb2e50 0x55e544eadb0e 0x55e544e4077a 0x55e544eaf86a 0x55e544eade0d 0x55e544e4077a 0x55e544eaf86a 0x55e544eadb0e 0x55e544e4077a 0x55e544eb2e50 0x55e544eadb0e 0x55e544ead813 0x55e544f77592
# Mean compute time for each iter: 0.041984785057022
# <Figure size 480x480 with 1 Axes>
# 164 violations out of 2016
# <Figure size 480x480 with 1 Axes>

# %%
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/inv_comp.py
# Out:
# (100, 21) (100, 21) (100, 21)

# %%
#4-15
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_4.py 15
# Out:
# Mean compute time for each iter: 0.008573104957779328
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 6
# <Figure size 480x480 with 1 Axes>

# %%
#4-25
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_4.py 25
# Out:
# Mean compute time for each iter: 0.008449549665431938
# <Figure size 480x480 with 1 Axes>
# 3 violations out of 6
# <Figure size 480x480 with 1 Axes>

# %%
#4-35
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_4.py 35
# Out:
# Mean compute time for each iter: 0.008366841830328136
# <Figure size 480x480 with 1 Axes>
# 3 violations out of 6
# <Figure size 480x480 with 1 Axes>

# %%
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/inv_comp.py
# Out:
# (100, 21) (100, 21) (100, 21)

# %%
#2-25
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_2.py 25
# Out:
# Mean compute time for each iter: 0.008484370722799358
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 1
# <Figure size 480x480 with 1 Axes>

# %%
#2-50
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_2.py 50
# Out:
# Mean compute time for each iter: 0.008494865918207264
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 1
# <Figure size 480x480 with 1 Axes>
