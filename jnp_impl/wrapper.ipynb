# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/inv_comp.py
# Out:
# (100, 21) (100, 21) (100, 21)

# %%
#16-15
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_16.py 15
# Out:
# Mean compute time for each iter: 0.0045810908049315185
# <Figure size 480x480 with 1 Axes>
# 216 violations out of 12000
# <Figure size 480x480 with 1 Axes>

# %%
#16-20
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_16.py 20
# Out:
# Mean compute time for each iter: 0.00463668099633447
# <Figure size 480x480 with 1 Axes>
# 276 violations out of 12000
# <Figure size 480x480 with 1 Axes>

# %%
#16-25
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_16.py 25
# Out:
# Mean compute time for each iter: 0.004602527952528334
# <Figure size 480x480 with 1 Axes>
# 247 violations out of 12000
# <Figure size 480x480 with 1 Axes>

# %%
#16-30
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_16.py 30
# Out:
# Mean compute time for each iter: 0.004581048085286214
# <Figure size 480x480 with 1 Axes>
# 285 violations out of 12000
# <Figure size 480x480 with 1 Axes>

# %%
#16-35
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_16.py 35
# Out:
# Mean compute time for each iter: 0.004662060761475587
# <Figure size 480x480 with 1 Axes>
# 421 violations out of 12000
# <Figure size 480x480 with 1 Axes>

# %%
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/inv_comp.py
# Out:
# (100, 21) (100, 21) (100, 21)

# %%
#32-12
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_32.py 12
# Out:
# Mean compute time for each iter: 0.004608120646204676
# <Figure size 480x480 with 1 Axes>
# 1667 violations out of 49600
# <Figure size 480x480 with 1 Axes>

# %%
#32-15
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_32.py 15
# Out:
# Mean compute time for each iter: 0.0045952174040648315
# <Figure size 480x480 with 1 Axes>
# 1366 violations out of 49600
# <Figure size 480x480 with 1 Axes>

# %%
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/inv_comp.py
# Out:
# (100, 21) (100, 21) (100, 21)

# %%
#8-10
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_8.py 10
# Out:
# Mean compute time for each iter: 0.004952621173572254
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 2800
# <Figure size 480x480 with 1 Axes>

# %%
#8-12
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_8.py 12
# Out:
# Mean compute time for each iter: 0.005014832432682927
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 2800
# <Figure size 480x480 with 1 Axes>

# %%
#8-15
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_8.py 15
# Out:
# Mean compute time for each iter: 0.004918825876963389
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 2800
# <Figure size 480x480 with 1 Axes>

# %%
#8-30
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_8.py 30
# Out:
# Mean compute time for each iter: 0.0049814695829863065
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 2800
# <Figure size 480x480 with 1 Axes>

# %%
#8-60
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_8.py 60
# Out:
# Mean compute time for each iter: 0.004909869786855337
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 2800
# <Figure size 480x480 with 1 Axes>

# %%
#8-120
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_8.py 120
# Out:
# Mean compute time for each iter: 0.004973178153281455
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 2800
# <Figure size 480x480 with 1 Axes>

# %%
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/inv_comp.py
# Out:
# (100, 21) (100, 21) (100, 21)
# tcmalloc: large alloc 1103159296 bytes == 0x556e86cea000 @  0x7f7bf103e1e7 0x7f7beebfe46e 0x7f7beec4ec7b 0x7f7beec4ed18 0x7f7beecf6010 0x7f7beecf673c 0x7f7beecf685d 0x556db49fc2f8 0x7f7beec3bef7 0x556db49f9fd7 0x556db49f9de0 0x556db4a6dac2 0x556db4a68b0e 0x556db49fb77a 0x556db4a6a86a 0x556db4a68b0e 0x556db493ae2b 0x7f7beec3bef7 0x556db49f9fd7 0x556db49f9de0 0x556db4a6dac2 0x556db4a68b0e 0x556db49fb77a 0x556db4a6a86a 0x556db49fb69a 0x556db4a69a45 0x556db4a68b0e 0x556db4a68813 0x556db4b32592 0x556db4b3290d 0x556db4b327b6
# ...

# %%
#64-12
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_64.py 12
# Out:
# tcmalloc: large alloc 2167611392 bytes == 0x55f0c968c000 @  0x7f758fe4b1e7 0x55f0a7961f48 0x55f0a792c9c7 0x7f755c7b1b32 0x7f755c9cc973 0x7f755c9d10bd 0x7f755c9d48ee 0x7f755c9dc5c0 0x7f755c9ce5f5 0x55f0a7930050 0x55f0a7a2199d 0x55f0a79a3fe9 0x55f0a799eb0e 0x55f0a793177a 0x55f0a799fc9e 0x55f0a799eb0e 0x55f0a793177a 0x55f0a799fc9e 0x55f0a799eb0e 0x55f0a793177a 0x55f0a799fa45 0x55f0a799eb0e 0x55f0a799e813 0x55f0a7a68592 0x55f0a7a6890d 0x55f0a7a687b6 0x55f0a7a40103 0x55f0a7a3fdac 0x7f758ec35bf7 0x55f0a7a3fc8a
# ...

# %%
#64-15
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_64.py 15
# Out:
# tcmalloc: large alloc 2167611392 bytes == 0x55e0e2dae000 @  0x7f0f1243b1e7 0x55e0c0b3ff48 0x55e0c0b0a9c7 0x7f0ededa1b32 0x7f0edefbc973 0x7f0edefc10bd 0x7f0edefc48ee 0x7f0edefcc5c0 0x7f0edefbe5f5 0x55e0c0b0e050 0x55e0c0bff99d 0x55e0c0b81fe9 0x55e0c0b7cb0e 0x55e0c0b0f77a 0x55e0c0b7dc9e 0x55e0c0b7cb0e 0x55e0c0b0f77a 0x55e0c0b7dc9e 0x55e0c0b7cb0e 0x55e0c0b0f77a 0x55e0c0b7da45 0x55e0c0b7cb0e 0x55e0c0b7c813 0x55e0c0c46592 0x55e0c0c4690d 0x55e0c0c467b6 0x55e0c0c1e103 0x55e0c0c1ddac 0x7f0f11225bf7 0x55e0c0c1dc8a
# ...

# %%
#64-20
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_64.py 20
# Out:
# tcmalloc: large alloc 2167611392 bytes == 0x559237a38000 @  0x7f30fe01c1e7 0x559215646f48 0x5592156119c7 0x7f30ca982b32 0x7f30cab9d973 0x7f30caba20bd 0x7f30caba58ee 0x7f30cabad5c0 0x7f30cab9f5f5 0x559215615050 0x55921570699d 0x559215688fe9 0x559215683b0e 0x55921561677a 0x559215684c9e 0x559215683b0e 0x55921561677a 0x559215684c9e 0x559215683b0e 0x55921561677a 0x559215684a45 0x559215683b0e 0x559215683813 0x55921574d592 0x55921574d90d 0x55921574d7b6 0x559215725103 0x559215724dac 0x7f30fce06bf7 0x559215724c8a
# ...

# %%
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/inv_comp.py
# Out:
# (100, 21) (100, 21) (100, 21)

# %%
#4-15
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_4.py 15
# Out:
# Mean compute time for each iter: 0.0051021590247168555
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 600
# <Figure size 480x480 with 1 Axes>

# %%
#4-25
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_4.py 25
# Out:
# Mean compute time for each iter: 0.00508028131586176
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 600
# <Figure size 480x480 with 1 Axes>

# %%
#4-35
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_4.py 35
# Out:
# Mean compute time for each iter: 0.005014958205046477
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 600
# <Figure size 480x480 with 1 Axes>

# %%
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/inv_comp.py
# Out:
# (100, 21) (100, 21) (100, 21)

# %%
#2-25
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_2.py 25
# Out:
# Mean compute time for each iter: 0.005161652932534585
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 100
# <Figure size 480x480 with 1 Axes>

# %%
#2-50
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# !python /content/drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot_2.py 50
# Out:
# Mean compute time for each iter: 0.0050830755147848045
# <Figure size 480x480 with 1 Axes>
# 0 violations out of 100
# <Figure size 480x480 with 1 Axes>
