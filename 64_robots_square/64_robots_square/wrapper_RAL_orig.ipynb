# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/64_robots_square/main_64_jax.py
# Out:
# Loading Matrices
# tcmalloc: large alloc 2167611392 bytes == 0x55eed797c000 @  0x7eff92b201e7 0x55eebd65ea18 0x55eebd629987 0x7eff5dda4b32 0x7eff5dfbf973 0x7eff5dfc40bd 0x7eff5dfc78ee 0x7eff5dfcf5c0 0x7eff5dfc15f5 0x55eebd62d010 0x55eebd71ec0d 0x55eebd6a10d8 0x55eebd69bc35 0x55eebd62e73a 0x55eebd69cd67 0x55eebd69bc35 0x55eebd62e73a 0x55eebd69cd67 0x55eebd69bc35 0x55eebd62e73a 0x55eebd69cb0e 0x55eebd69bc35 0x55eebd69b933 0x55eebd765402 0x55eebd76577d 0x55eebd765626 0x55eebd73d313 0x55eebd73cfbc 0x7eff9190abf7 0x55eebd73ce9a
# Starting Actual Computation
# ...

# %%
# !python /content/drive/MyDrive/43/main_3D.py
# Out:
# 2021-09-16 16:57:49.234582: W external/org_tensorflow/tensorflow/compiler/xla/service/gpu/gemm_algorithm_picker.cc:206] Failed to find best cuBLAS algorithm, GEMM performance might be suboptimal: Internal: All algorithms tried for %custom-call = f64[11,11]{1,0} custom-call(f64[11,100]{1,0} %parameter.1, f64[100,11]{1,0} %parameter.2), custom_call_target="__cublas$gemm", metadata={op_type="dot_general" op_name="dot_general[ dimension_numbers=(((1,), (0,)), ((), ()))\n             precision=None\n             preferred_element_type=None ]"}, backend_config="{\"alpha_real\":1,\"alpha_imag\":0,\"beta\":0,\"dot_dimension_numbers\":{\"lhs_contracting_dimensions\":[\"1\"],\"rhs_contracting_dimensions\":[\"0\"],\"lhs_batch_dimensions\":[],\"rhs_batch_dimensions\":[]},\"batch_size\":\"1\",\"lhs_stride\":\"1100\",\"rhs_stride\":\"1100\"}" failed. Falling back to default algorithm.
# ...

# %%
# !python /content/drive/MyDrive/64_robots_square/new_plot.py 12
# Out:
# <Figure size 640x480 with 0 Axes>

# %%
# !ffmpeg -r 10 -f image2 -i /content/drive/MyDrive/64_robots_square/data/16_agents_%d.jpg -s 1000x1000 -pix_fmt yuv420p -y /content/drive/MyDrive/64_robots_square/simulation.mp4
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...
