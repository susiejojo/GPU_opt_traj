# %%
# import cupy as cp
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cd /content/drive/MyDrive/GPU_opt_traj/

# %%
# !python drive/MyDrive/GPU_opt_traj/cupy_impl/inv_comp.py
# Out:
# (100, 21) (100, 21) (100, 21)

# %%
# !python drive/MyDrive/GPU_opt_traj/cupy_impl/main_traj.py
# Out:
# [7.00000000e+00 2.94000000e+01 1.23480000e+02 5.18616000e+02
#  2.17818720e+03 9.14838624e+03 3.97601649e+05 2.46513022e+06
#  1.52838074e+07 9.47596058e+07]
# Iter # 0
# 0.06427587791557138 4.000000000000019 0.09999999999983769
# 4.164275877915428
# Iter # 1
# 0.06645126757483813 7.999999999999961 0.00485927926060379
# 8.071310546835402
# Iter # 2
# 0.0632769002628807 0.06612395501804352 0.01847615505316258
# 0.1478770103340868
# Iter # 3
# 0.059355865991305615 0.06420025663999793 0.018340846815745937
# 0.1418969694470495
# Iter # 4
# 0.06701464884170216 0.07151997675739472 0.020758003976473607
# 0.1592926295755705
# Iter # 5
# 0.06980287076081565 0.07379841833232864 0.017993405766065798
# 0.16159469485921008
# Iter # 6
# 0.07078140035583497 0.07420211788174237 0.02350774009824194
# 0.16849125833581927
# Iter # 7
# 0.0710389271686804 0.07403885977729413 0.023239780839209565
# 0.16831756778518409
# Iter # 8
# 0.07118036140342339 0.07347721074584182 0.023102835973382238
# ...

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 10] # Adjust the Height and Width 
plt.rcParams['figure.dpi'] = 100   # and DPI to your liking
# %run drive/MyDrive/GPU_opt_traj/cupy_impl/new_plot.py

# %%
# !python drive/MyDrive/GPU_opt_traj/jnp_impl/inv_comp.py
# Out:
# (100, 21) (100, 21) (100, 21)

# %%
# !python drive/MyDrive/GPU_opt_traj/jnp_impl/main_traj.py
# Out:
# [7.00000000e+00 2.94000000e+01 1.23480000e+02 5.18616000e+02
#  2.17818720e+03 9.14838624e+03 3.97601649e+05 2.46513022e+06
#  1.52838074e+07 9.47596058e+07]
# Iter # 0
# 0.422716822299423 0.4227171735653191 0.005477095766664087
# Iter # 1
# 0.39836523340418994 0.4266185348759942 0.12578262993886602
# Iter # 2
# 0.37603122828237334 0.38465638755998627 0.17921253846558716
# Iter # 3
# 0.3607970959944059 0.3761427185015809 0.2032086606773622
# Iter # 4
# 0.34184227242465504 0.3662660002948777 0.20869587988885857
# Iter # 5
# 0.33027605910193814 0.3627188721878462 0.23099387948458394
# Iter # 6
# 0.3196556541173553 0.3571879668854915 0.24709353086564612
# Iter # 7
# 0.3106605039511724 0.352717616630262 0.1931759379765829
# Iter # 8
# 0.3023705329075912 0.3408848643663608 0.20451060998659254
# Iter # 9
# 0.29031036621036627 0.32795421180225015 0.20819579648664044
# Iter # 10
# 0.27837822101118254 0.31399552009227216 0.225113526629926
# Iter # 11
# ...

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 10] # Adjust the Height and Width 
plt.rcParams['figure.dpi'] = 100   # and DPI to your liking
# %run drive/MyDrive/GPU_opt_traj/jnp_impl/new_plot.py
